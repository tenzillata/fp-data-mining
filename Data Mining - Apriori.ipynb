# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from apyori import apriori

# %%
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('data_transaksi.xlsx')

# %%
df.head(10)
# Out:
#    Customer_ID  No_Transaksi    Tanggal  \
# 0        10253        548252 2017-04-04
# 1        10104        548253 2017-04-05
# 2        10271        548530 2017-04-06
# 3        10257        548436 2017-04-07
# 4        10281        548442 2017-04-08
# 5        10181        548400 2017-04-10
# 6        10303        548250 2017-04-11
# 7        10186        548367 2017-04-14
# 8        10131        548477 2017-04-15
# 9        10016        548486 2017-04-16
#
#                                                Items  Unnamed: 4  Unnamed: 5  \
# 0                      Telur, Minyak, Permen, Tepung         NaN         NaN
# 1                       Deterjen, Kecap, Susu, Sabun         NaN         NaN
# 2        Telur, Minyak, Kecap, Snack, Permen, Tepung         NaN         NaN
# 3                             Deterjen, Kecap, Sabun         NaN         NaN
# 4        Telur, Minyak, Kecap, Snack, Permen, Tepung         NaN         NaN
# 5  Telur, Deterjen, Minyak, Sabun, Snack, Permen,...         NaN         NaN
# 6     Telur, Deterjen, Minyak, Snack, Permen, Tepung         NaN         NaN
# 7                 Telur, Kecap, Sabun, Snack, Permen         NaN         NaN
# 8  Telur, Minyak, Kecap, Susu, Snack, Permen, Tepung         NaN         NaN
# 9       Telur, Deterjen, Minyak, Kecap, Susu, Tepung         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9
# 0         0.0         NaN         NaN      Telur
# 1         NaN         NaN         NaN        NaN
# 2         NaN         NaN         NaN        NaN
# 3         NaN         NaN         NaN        NaN
# 4         NaN         NaN         NaN        NaN
# 5         NaN         NaN         NaN        NaN
# 6         NaN         NaN         NaN        NaN
# 7         NaN         NaN         NaN        NaN
# 8         NaN         NaN         NaN        NaN
# 9         NaN         NaN         NaN        NaN

# %%
df.dropna(axis=1)
# Out:
#      Customer_ID  No_Transaksi    Tanggal  \
# 0          10253        548252 2017-04-04
# 1          10104        548253 2017-04-05
# 2          10271        548530 2017-04-06
# 3          10257        548436 2017-04-07
# 4          10281        548442 2017-04-08
# ..           ...           ...        ...
# 345        10218        548423 2018-11-20
# 346        10251        548239 2018-11-21
# 347        10342        548216 2018-11-21
# 348        10242        548218 2018-11-22
# 349        10167        548469 2018-11-22
#
#                                            Items
# 0                  Telur, Minyak, Permen, Tepung
# 1                   Deterjen, Kecap, Susu, Sabun
# 2    Telur, Minyak, Kecap, Snack, Permen, Tepung
# 3                         Deterjen, Kecap, Sabun
# 4    Telur, Minyak, Kecap, Snack, Permen, Tepung
# ..                                           ...
# 345              Telur, Deterjen, Minyak, Tepung
# 346      Telur, Deterjen, Minyak, Permen, Tepung
# 347          Telur, Minyak, Sabun, Snack, Tepung
# 348                        Telur, Minyak, Tepung
# 349          Telur, Minyak, Sabun, Snack, Tepung
#
# [350 rows x 4 columns]

# %%
data=df.drop(['Customer_ID','No_Transaksi','Tanggal'],axis=1)

# %%
records = []
for i in range(data.shape[0]):
    records.append([str(data.values[i,j]).split(',') for j in range(data.shape[1])])

trx = [[] for trx in range(len(records))]
for i in range(len(records)):
    for j in records[i][0]:
        trx[i].append(j)
trx
# Out:
# [['Telur', ' Minyak', ' Permen', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Sabun'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Kecap', ' Sabun', ' Snack', ' Permen'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun', ' Snack'],
#  ['Deterjen', ' Minyak', ' Susu', ' Permen'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Permen'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Deterjen', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Permen'],
#  ['Telur', ' Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Deterjen', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Tepung'],
#  ['Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Kecap', ' Susu'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Permen'],
#  ['Deterjen', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Sabun', ' Tepung'],
#  ['Telur', ' Minyak', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Snack', ' Permen'],
#  ['Minyak', ' Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Kecap', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Snack'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Permen'],
#  ['Telur', ' Deterjen', ' Kecap', ' Susu', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Susu'],
#  ['Telur', ' Minyak', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Permen', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Snack', ' Permen'],
#  ['Minyak', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Sabun'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Snack'],
#  ['Telur', ' Minyak', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Kecap', ' Susu', ' Snack', ' Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Kecap', ' Susu', ' Sabun', ' Snack', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Permen', ' Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Deterjen', ' Susu', ' Permen'],
#  ['Telur', ' Minyak', ' Snack', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Snack', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun', ' Snack'],
#  ['Telur', ' Deterjen', ' Permen'],
#  ['Kecap', ' Permen', ' Tepung'],
#  ['Deterjen', ' Snack', ' Permen'],
#  ['Telur', ' Minyak', ' Kecap', ' Sabun', ' Permen', ' Tepung'],
#  ['Susu', ' Snack', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Minyak'],
#  ['Telur', ' Deterjen', ' Kecap', ' Snack'],
#  ['Telur', ' Deterjen', ' Snack'],
#  ['Telur', ' Minyak', ' Kecap', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Permen', ' Tepung'],
#  ['Kecap', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Snack'],
#  ['Deterjen', ' Minyak', ' Kecap', ' Susu', ' Snack', ' Permen'],
#  ['Telur', ' Deterjen', ' Kecap', ' Sabun', ' Snack'],
#  ['Telur', ' Minyak', ' Sabun', ' Tepung'],
#  ['Telur',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Permen', ' Tepung'],
#  ['Minyak', ' Susu', ' Sabun', ' Snack'],
#  ['Deterjen', ' Minyak', ' Kecap', ' Permen'],
#  ['Telur', ' Kecap', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Sabun', ' Tepung'],
#  ['Minyak', ' Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun'],
#  ['Telur', ' Susu', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Sabun', ' Snack', ' Permen'],
#  ['Telur', ' Susu', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Tepung'],
#  ['Telur', ' Kecap', ' Sabun', ' Snack', ' Permen'],
#  ['Deterjen', ' Susu', ' Tepung'],
#  ['Telur', ' Sabun', ' Snack'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Tepung'],
#  ['Kecap', ' Permen'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Kecap', ' Sabun', ' Snack', ' Tepung'],
#  ['Minyak', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Susu', ' Permen'],
#  ['Telur', ' Minyak', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Deterjen', ' Minyak', ' Susu', ' Permen', ' Tepung'],
#  ['Susu', ' Sabun', ' Snack', ' Permen'],
#  ['Minyak', ' Kecap', ' Sabun', ' Snack'],
#  ['Telur', ' Deterjen', ' Kecap', ' Susu', ' Sabun'],
#  ['Deterjen', ' Minyak', ' Sabun', ' Permen', ' Tepung'],
#  ['Minyak', ' Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Kecap', ' Susu', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Kecap', ' Sabun'],
#  ['Telur', ' Snack', ' Tepung'],
#  ['Telur', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Sabun', ' Tepung'],
#  ['Minyak', ' Kecap', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Snack'],
#  ['Telur', ' Minyak', ' Kecap', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Deterjen', ' Minyak', ' Kecap', ' Susu', ' Tepung'],
#  ['Deterjen', ' Minyak', ' Kecap', ' Snack', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Tepung'],
#  ['Telur', ' Deterjen', ' Kecap', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Sabun', ' Snack'],
#  ['Deterjen', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Snack'],
#  ['Kecap', ' Sabun'],
#  ['Kecap', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Snack', ' Permen'],
#  ['Telur', ' Deterjen', ' Snack', ' Permen'],
#  ['Deterjen', ' Snack'],
#  ['Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Kecap', ' Susu', ' Snack', ' Permen'],
#  ['Telur', ' Minyak', ' Susu'],
#  ['Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Susu'],
#  ['Deterjen', ' Sabun', ' Tepung'],
#  ['Telur', ' Sabun', ' Permen'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Permen'],
#  ['Telur', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Snack'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Permen', ' Tepung'],
#  ['Kecap', ' Snack', ' Permen'],
#  ['Telur', ' Minyak', ' Susu', ' Tepung'],
#  ['Telur', ' Deterjen', ' Susu', ' Snack', ' Permen'],
#  ['Deterjen', ' Minyak', ' Sabun', ' Snack'],
#  ['Telur', ' Deterjen', ' Sabun', ' Permen', ' Tepung'],
#  ['Susu', ' Sabun'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Tepung'],
#  ['Sabun', ' Snack', ' Permen'],
#  ['Telur', ' Kecap', ' Susu', ' Snack', ' Permen'],
#  ['Minyak', ' Susu', ' Sabun', ' Snack', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Kecap'],
#  ['Telur', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Sabun', ' Permen'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Snack'],
#  ['Telur', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Snack', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Kecap'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Deterjen', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Deterjen', ' Minyak', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Snack'],
#  ['Kecap', ' Susu', ' Sabun'],
#  ['Minyak', ' Kecap', ' Susu', ' Permen'],
#  ['Telur', ' Minyak', ' Snack', ' Permen'],
#  ['Telur', ' Deterjen', ' Kecap', ' Susu', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Permen', ' Tepung'],
#  ['Minyak', ' Kecap'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Tepung'],
#  ['Telur', ' Deterjen', ' Kecap', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Snack'],
#  ['Telur', ' Minyak', ' Sabun', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Permen'],
#  ['Telur', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Deterjen', ' Minyak', ' Sabun', ' Permen'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Susu'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Snack', ' Permen'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Kecap', ' Sabun', ' Snack'],
#  ['Minyak', ' Kecap', ' Permen'],
#  ['Telur', ' Minyak', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Deterjen', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Snack', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Snack', ' Tepung'],
#  ['Susu'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Permen', ' Tepung'],
#  ['Susu', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Kecap', ' Sabun'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Permen', ' Tepung'],
#  ['Minyak', ' Susu'],
#  ['Telur', ' Minyak', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Snack', ' Permen'],
#  ['Telur', ' Minyak', ' Susu', ' Snack', ' Tepung'],
#  ['Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Permen', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Permen', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Permen'],
#  ['Telur', ' Deterjen', ' Minyak', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Tepung'],
#  ['Telur', ' Minyak', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Permen', ' Tepung'],
#  ['Susu', ' Sabun'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Sabun', ' Tepung'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Snack', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun'],
#  ['Telur', ' Minyak', ' Kecap', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Snack'],
#  ['Deterjen', ' Susu', ' Sabun', ' Snack'],
#  ['Telur', ' Deterjen', ' Minyak', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Kecap', ' Snack', ' Permen'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Sabun', ' Permen', ' Tepung'],
#  ['Deterjen', ' Susu', ' Sabun', ' Snack'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Snack'],
#  ['Telur', ' Deterjen', ' Kecap', ' Susu', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Sabun', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Sabun', ' Snack', ' Permen', ' Tepung'],
#  ['Minyak', ' Kecap', ' Susu', ' Snack', ' Permen'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Deterjen', ' Sabun', ' Tepung'],
#  ['Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Minyak', ' Kecap', ' Susu', ' Sabun', ' Snack'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur',
#   ' Deterjen',
#   ' Minyak',
#   ' Kecap',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun', ' Snack'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Snack', ' Permen', ' Tepung'],
#  ['Susu', ' Sabun', ' Snack'],
#  ['Deterjen', ' Susu', ' Sabun'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Tepung'],
#  ['Deterjen', ' Kecap', ' Susu', ' Sabun'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Tepung'],
#  ['Permen'],
#  ['Kecap', ' Susu', ' Sabun'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Snack', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Kecap', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Susu', ' Tepung'],
#  ['Telur', ' Minyak', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Sabun', ' Permen', ' Tepung'],
#  ['Deterjen', ' Snack'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Snack', ' Permen'],
#  ['Telur',
#   ' Minyak',
#   ' Kecap',
#   ' Susu',
#   ' Sabun',
#   ' Snack',
#   ' Permen',
#   ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Snack', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Permen', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Permen', ' Tepung'],
#  ['Minyak', ' Kecap', ' Susu', ' Sabun', ' Snack'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Susu', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Kecap', ' Permen'],
#  ['Minyak', ' Kecap', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Susu', ' Sabun', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Tepung'],
#  ['Telur', ' Deterjen', ' Minyak', ' Permen', ' Tepung'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Tepung'],
#  ['Telur', ' Minyak', ' Tepung'],
#  ['Telur', ' Minyak', ' Sabun', ' Snack', ' Tepung']]

# %% [markdown]
# # Minimal Support 20%

# %%
# Menggunakan fungsi apriori untuk membuat asosiasi
association_rules = apriori(trx, min_support=0.20, min_confidence=0.80,min_lift=1)
# Membuat list hasil dari algoritma apriori
association_results = association_rules

# %%
# Menampilkan hasil asosiasi dari item 
pd.set_option('max_colwidth', 1000)
Result=pd.DataFrame(columns=['Rule','Support','Confidence'])
for item in association_results:
    pair = item[2]
    for i in pair:
        items = str([x for x in i[0]])
        if i[3]!=1:
            Result=Result.append({
                'Rule':str([x for x in i[0]])+ " -> " +str([x for x in i[1]]),
                'Support':str(round(item[1]*100,2))+'%',
                'Confidence':str(round(i[2] *100,2))+'%'
                },ignore_index=True)
Result
# Out:
#                                                 Rule Support Confidence
# 0                         [' Deterjen'] -> ['Telur']  33.71%     100.0%
# 1                         [' Minyak'] -> [' Tepung']  50.29%     81.86%
# 2                           [' Minyak'] -> ['Telur']  57.43%     93.49%
# 3                           [' Tepung'] -> ['Telur']  56.57%     83.54%
# 4            [' Minyak', ' Deterjen'] -> [' Tepung']  22.57%     84.95%
# 5            [' Tepung', ' Deterjen'] -> [' Minyak']  22.57%     87.78%
# 6              [' Minyak', ' Deterjen'] -> ['Telur']  26.57%     100.0%
# 7              [' Tepung', ' Deterjen'] -> ['Telur']  25.71%     100.0%
# 8               [' Minyak', ' Kecap'] -> [' Tepung']  26.57%      82.3%
# 9               [' Kecap', ' Tepung'] -> [' Minyak']  26.57%      82.3%
# 10                [' Minyak', ' Kecap'] -> ['Telur']   30.0%     92.92%
# 11                [' Kecap', 'Telur'] -> [' Minyak']   30.0%      81.4%
# 12                [' Kecap', ' Tepung'] -> ['Telur']  28.57%      88.5%
# 13             [' Minyak', ' Permen'] -> [' Tepung']  28.29%     81.82%
# 14               [' Minyak', ' Permen'] -> ['Telur']  31.14%     90.08%
# 15               [' Permen', 'Telur'] -> [' Minyak']  31.14%     83.21%
# 16              [' Minyak', ' Sabun'] -> [' Tepung']   24.0%      80.0%
# 17                [' Minyak', ' Sabun'] -> ['Telur']  28.29%     94.29%
# 18                ['Telur', ' Sabun'] -> [' Minyak']  28.29%     80.49%
# 19              [' Minyak', ' Snack'] -> [' Tepung']  25.43%     80.91%
# 20                [' Minyak', ' Snack'] -> ['Telur']  29.14%     92.73%
# 21               [' Minyak', ' Susu'] -> [' Tepung']  22.29%     82.11%
# 22                 [' Minyak', ' Susu'] -> ['Telur']  25.71%     94.74%
# 23                 [' Susu', 'Telur'] -> [' Minyak']  25.71%     80.36%
# 24               [' Minyak', ' Tepung'] -> ['Telur']  48.57%     96.59%
# 25               [' Minyak', 'Telur'] -> [' Tepung']  48.57%     84.58%
# 26               ['Telur', ' Tepung'] -> [' Minyak']  48.57%     85.86%
# 27               [' Permen', ' Tepung'] -> ['Telur']  29.71%     83.87%
# 28                [' Tepung', ' Sabun'] -> ['Telur']   28.0%     85.22%
# 29                [' Snack', ' Tepung'] -> ['Telur']  28.86%     84.17%
# 30                 [' Susu', ' Tepung'] -> ['Telur']  25.14%     83.81%
# 31  [' Minyak', ' Deterjen'] -> ['Telur', ' Tepung']  22.57%     84.95%
# 32  [' Tepung', ' Deterjen'] -> [' Minyak', 'Telur']  22.57%     87.78%
# 33  [' Minyak', ' Tepung', ' Deterjen'] -> ['Telur']  22.57%     100.0%
# 34  [' Minyak', 'Telur', ' Deterjen'] -> [' Tepung']  22.57%     84.95%
# 35  ['Telur', ' Tepung', ' Deterjen'] -> [' Minyak']  22.57%     87.78%
# 36     [' Minyak', ' Kecap', ' Tepung'] -> ['Telur']  25.71%     96.77%
# 37     [' Minyak', ' Kecap', 'Telur'] -> [' Tepung']  25.71%     85.71%
# 38     [' Kecap', ' Tepung', 'Telur'] -> [' Minyak']  25.71%      90.0%
# 39    [' Minyak', ' Tepung', ' Permen'] -> ['Telur']  26.86%     94.95%
# 40    [' Minyak', 'Telur', ' Permen'] -> [' Tepung']  26.86%     86.24%
# 41    [' Permen', 'Telur', ' Tepung'] -> [' Minyak']  26.86%     90.38%
# 42     [' Minyak', ' Tepung', ' Sabun'] -> ['Telur']  23.43%     97.62%
# 43     [' Minyak', 'Telur', ' Sabun'] -> [' Tepung']  23.43%     82.83%
# 44     ['Telur', ' Tepung', ' Sabun'] -> [' Minyak']  23.43%     83.67%
# 45     [' Minyak', ' Snack', ' Tepung'] -> ['Telur']  24.57%     96.63%
# 46     [' Minyak', 'Telur', ' Snack'] -> [' Tepung']  24.57%     84.31%
# 47     ['Telur', ' Snack', ' Tepung'] -> [' Minyak']  24.57%     85.15%
# 48      [' Minyak', ' Susu'] -> ['Telur', ' Tepung']  21.71%      80.0%
# 49      [' Minyak', ' Susu', ' Tepung'] -> ['Telur']  21.71%     97.44%
# 50      [' Minyak', 'Telur', ' Susu'] -> [' Tepung']  21.71%     84.44%
# 51      [' Susu', 'Telur', ' Tepung'] -> [' Minyak']  21.71%     86.36%

# %% [markdown]
# # Minimal Support 30%

# %%
# Menggunakan fungsi apriori untuk membuat asosiasi
association_rules = apriori(trx, min_support=0.30, min_confidence=0.80,min_lift=1)
# Membuat list hasil dari algoritma apriori
association_results = association_rules

# %%
# Menampilkan hasil asosiasi dari item 
pd.set_option('max_colwidth', 1000)
Result=pd.DataFrame(columns=['Rule','Support','Confidence'])
for item in association_results:
    pair = item[2]
    for i in pair:
        items = str([x for x in i[0]])
        if i[3]!=1:
            Result=Result.append({
                'Rule':str([x for x in i[0]])+ " -> " +str([x for x in i[1]]),
                'Support':str(round(item[1]*100,2))+'%',
                'Confidence':str(round(i[2] *100,2))+'%'
                },ignore_index=True)
Result
# Out:
#                                    Rule Support Confidence
# 0            [' Deterjen'] -> ['Telur']  33.71%     100.0%
# 1            [' Minyak'] -> [' Tepung']  50.29%     81.86%
# 2              [' Minyak'] -> ['Telur']  57.43%     93.49%
# 3              [' Tepung'] -> ['Telur']  56.57%     83.54%
# 4    [' Minyak', ' Kecap'] -> ['Telur']   30.0%     92.92%
# 5    [' Kecap', 'Telur'] -> [' Minyak']   30.0%      81.4%
# 6   [' Minyak', ' Permen'] -> ['Telur']  31.14%     90.08%
# 7   [' Permen', 'Telur'] -> [' Minyak']  31.14%     83.21%
# 8   [' Minyak', ' Tepung'] -> ['Telur']  48.57%     96.59%
# 9   [' Minyak', 'Telur'] -> [' Tepung']  48.57%     84.58%
# 10  ['Telur', ' Tepung'] -> [' Minyak']  48.57%     85.86%

# %% [markdown]
# # Minimal Support 40%

# %%
# Menggunakan fungsi apriori untuk membuat asosiasi
association_rules = apriori(trx, min_support=0.40, min_confidence=0.80,min_lift=1)
# Membuat list hasil dari algoritma apriori
association_results = association_rules

# %%
# Menampilkan hasil asosiasi dari item 
pd.set_option('max_colwidth', 1000)
Result=pd.DataFrame(columns=['Rule','Support','Confidence'])
for item in association_results:
    pair = item[2]
    for i in pair:
        items = str([x for x in i[0]])
        if i[3]!=1:
            Result=Result.append({
                'Rule':str([x for x in i[0]])+ " -> " +str([x for x in i[1]]),
                'Support':str(round(item[1]*100,2))+'%',
                'Confidence':str(round(i[2] *100,2))+'%'
                },ignore_index=True)
Result
# Out:
#                                   Rule Support Confidence
# 0           [' Minyak'] -> [' Tepung']  50.29%     81.86%
# 1             [' Minyak'] -> ['Telur']  57.43%     93.49%
# 2             [' Tepung'] -> ['Telur']  56.57%     83.54%
# 3  [' Minyak', ' Tepung'] -> ['Telur']  48.57%     96.59%
# 4  [' Minyak', 'Telur'] -> [' Tepung']  48.57%     84.58%
# 5  ['Telur', ' Tepung'] -> [' Minyak']  48.57%     85.86%
